# %% [markdown]
# Q1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top 5 and bottom 5 records.

# %%
# Importing required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the provided dataset
df = pd.read_csv('C:/Users/deepa/Python week 3/youtube_dislike_dataset.csv')

# %%
# To view the loaded dataset
df
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# By taking a copy of the data we can alter the changes in the copied data if any changes occurs we can find the difference between the actual and the copied data or any error that are made can be easily changed  and no need to run the data from the first.

# %%
df_copy = df.copy()

# %%
# for retrieving first 5 data we use head() function.
df_copy.head()
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
# for retrieving last 5 data we use tail() function
df_copy.tail()
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# Q2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
# To check the information of the dataframe we use .info() function
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
# To check the shape of the dataframe we use .shape() function
df_copy.shape
# Out:
# (37422, 12)

# %%
# To check the datatypes of the dataframe we use .dtypes
df_copy.dtypes
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object

# %% [markdown]
# Inference :
# 1. The given data is a class of DataFrame.
# 2. Comments column has some missing (null values) with a count of 158 null values.
# 3. Shape of the dataset is 37422 rows and 12 columns.
# 4. 8 columns are object datatype and 4 columns are integer datatype.
# 5. published_at column can be converted into numerical column for analysis.

# %% [markdown]
# Q3. Check for the Percentage of the missing values and drop or impute them.

# %%
df_copy.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
#percentage of missing values
df_copy.isnull().sum()*100/len(df)
# Out:
# video_id         0.000000
# title            0.000000
# channel_id       0.000000
# channel_title    0.000000
# published_at     0.000000
# view_count       0.000000
# likes            0.000000
# dislikes         0.000000
# comment_count    0.000000
# tags             0.000000
# description      0.000000
# comments         0.422212
# dtype: float64

# %% [markdown]
# Percentage of missing values in comments is 0.422% and so we can drop the missing values in the comments column

# %%
#Dropping missing values in comments column using .dropna() function.
df_copy = df_copy.dropna()

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37264 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37264 non-null  object
#  1   title          37264 non-null  object
#  2   channel_id     37264 non-null  object
#  3   channel_title  37264 non-null  object
#  4   published_at   37264 non-null  object
#  5   view_count     37264 non-null  int64
#  6   likes          37264 non-null  int64
#  7   dislikes       37264 non-null  int64
#  8   comment_count  37264 non-null  int64
#  9   tags           37264 non-null  object
#  10  description    37264 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.7+ MB

# %% [markdown]
# Q4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
# For taking summary statistics for both numerical and categorical columns we can use .include() function in describe for dataframe.
df_copy.describe(include='all').T
# Out:
#                  count unique  \
# video_id         37264  37264
# title            37264  36958
# channel_id       37264  10891
# channel_title    37264  10813
# published_at     37264  36617
# view_count     37264.0    NaN
# likes          37264.0    NaN
# dislikes       37264.0    NaN
# comment_count  37264.0    NaN
# tags             37264  28705
# description      37264  35479
# comments         37264  37264
#
#                                                              top  freq  \
# video_id                                             --0bCF-iK2E     1
# title                                                        www    21
# channel_id                              UCNAf1k0yIjyGu3k9BwAg3lg   533
# channel_title                                Sky Sports Football   533
# published_at                                 2020-10-16 04:00:10     6
# view_count                                                   NaN   NaN
# ...

# %% [markdown]
# Inference for Categorical columns:
# 1) video_id: The video id of 37,264 has there own unique values,There are no duplicate values in this column and Top value is --0bCF-iK2E
# 2) title: There are nearly 36,958 titles are unique among 37,264, 306 of them are duplicated and frequently occurred value is 21 and top value is www.
# 3) channel_id: 10,891 id's are unqiue among 37,264, around 26,373 id's are duplicates and frequently occurred is nearly 533 and top value is UCNAf1k0yIjyGu3k9BwAg3lg.
# 4) channel_title: 10,813 titles are unique among 37,264. frequently occurred is nearly same as id 533 and top value is Sky Sports Football.
# 5) published_at: 36,617 published are unique, frequently occurrend is 6 and top value is 2020-10-16 04:00:10	.
# 6) tags: 28,705 tags are unique in 37,264, frequently occurred is 3808.
# 7) description: 35,479 descriptions are unique,frequently occurred is 587.
# 8) comments: Obviously 37,264 unique comments are there and top is Respect to Dortmund fans,must be sad losing hi...	.

# %% [markdown]
# Inference for numerical columns:
#
# 1) view_count: Mean value is greater than the median value which stats that skewness is positively distributed,
#                The maximum view count is 1322796924.0 and the minimum view count is 20368.0,
#                The Standard deviation is  24313037.507113.
#
# 2) likes: Mean value is greater than the median value which stats that skewness is positively distributed,
#           The maximum likes is 31837675.0 and the minimum likes is 22.0.
#           The Standard Deviation is 538493.102692.
#
# 3) dislikes: Mean value is greater than the median value which stats that skewness is positively distributed,
#              The maximum dislike is 2397733.0 and the minimum dislike is 3.
#              The Standard Deviation is 30751.937841.
#
# 4) comment_count: Mean value is greater than the median value which stats that skewness is positively distributed,
#                   The maximum comment count is 16071029.0 and minimum comment count is 1.
#                   The Standard Deviation is 117346.466567

# %% [markdown]
# Q5. Convert datatype of column published_at from object to pandas datetime.

# %%
# The published_at datatype can be converted into datetime by using pd.to_datetime() function.
df_copy['published_at'] = pd.to_datetime(df_copy['published_at'])

# %%
df_copy
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
# Now, we can see that the published_at datatype has been changed to datetime from objectdatatype to datetime datatype in the info
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37264 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37264 non-null  object
#  1   title          37264 non-null  object
#  2   channel_id     37264 non-null  object
#  3   channel_title  37264 non-null  object
#  4   published_at   37264 non-null  datetime64[ns]
#  5   view_count     37264 non-null  int64
#  6   likes          37264 non-null  int64
#  7   dislikes       37264 non-null  int64
#  8   comment_count  37264 non-null  int64
#  9   tags           37264 non-null  object
#  10  description    37264 non-null  object
#  11  comments       37264 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 3.7+ MB

# %% [markdown]
# Q6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
# By using published_at column we can easily create a new column named published_month with only month by using .dt.month() function
df_copy['published_month'] = df_copy['published_at'].dt.month

# %%
# The published _month column only has month in it
df_copy
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# Q7. Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'
# and so on.....

# %%
#We can create a dictionary to convert months as name and store it in a variable and apply it to the dataframe.
months_name = {1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'}

# The converted one is replaced to the published_month by using .replace() function
df_copy['published_month'] = df_copy['published_month'].replace(months_name)

# %%
# Now the changed value will be displayed in the data by calling it
df_copy
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# Q8. Find the number of videos published each month and arrange the months in a decreasing order based
# on the video count.

# %%
# By using groupby function we group only 'published_month' & 'video_id' columns
# sorting then in descending order by using .sort_values() function
# and finally we use .count() function to find the total count of the videos in each months.

df_copy.groupby('published_month')['video_id'].count().sort_values(ascending=False)
# Out:
# published_month
# Oct    4976
# Sep    4854
# Nov    4821
# Aug    4250
# Dec    3063
# Jul    2331
# Jun    2305
# Mar    2248
# Feb    2125
# Apr    2119
# Jan    2099
# May    2073
# Name: video_id, dtype: int64

# %% [markdown]
# Q9. Find the count of unique video_id, channel_id and channel_title.

# %%
# using nunique() function we can find the total count of unique values in the video_id column

unique_video_count = df_copy['video_id'].nunique()
print("Count of unique video_id:", unique_video_count)
# Out:
# Count of unique video_id: 37264

# %%
# using nunique() function we can find the total count of unique values in the channel_id column

unique_channel_id_count = df_copy['channel_id'].nunique()
print('Count of unique channel_id:', unique_channel_id_count)
# Out:
# Count of unique channel_id: 10891

# %%
# using nunique() function we can find the total count of unique values in the channel_title column

unique_channel_title = df_copy['channel_title'].nunique()
print('Count of unique channel_title:', unique_channel_title)
# Out:
# Count of unique channel_title: 10813

# %% [markdown]
# Q10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10
# having lowest number of videos.

# %%
# Using groupby function for channel_title & video_id and use count() function to fnd the total count of the videos of each channel.
# Now sort them using .sort_values and give ascending=false, so that we get all highest numebr of videos in the channels
# to get top 10 we use .head(10) for the first top 10 channels of the dataset.

top_10 = df_copy.groupby('channel_title')['video_id'].count().sort_values(ascending=False).head(10)
print('The top 10 channels having highest number of videos are:','\n',top_10)
# Out:
# The top 10 channels having highest number of videos are:
#  channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: video_id, dtype: int64

# %%
# Using groupby function for channel_title & video_id and use count() function to fnd the total count of the videos of each channel.
# Now sort them using .sort_values and give ascending=False, so that we get all Lowest number of videos in the channels
# to get bottom 10 we use .tail(10) for the bottom 10 channels of the dataset.

bottom_10 = df_copy.groupby('channel_title')['video_id'].count().sort_values(ascending=False).tail(10)
print("The bootom 10 channels having lowest number of videos are:",'\n',bottom_10)
# Out:
# The bootom 10 channels having lowest number of videos are:
#  channel_title
# Karikku Tuned      1
# Karen Bustillos    1
# Karen Aslanyan     1
# Karchez            1
# Karate Combat      1
# Kaptain Kuba       1
# Kanye West         1
# Kannur kitchen     1
# Kannada Cinema     1
# zoom               1
# Name: video_id, dtype: int64

# %% [markdown]
# Q11. Find the title of the video which has the maximum number of likes and the title of the video having
# minimum likes and write your inferences.

# %%
# Using groupby function for title & likes columns, to find maximum videos of likes use .max() function.
# sort them using sort_values() give ascending = false, we get the video that has maximum likes using.head(1)

df_copy.groupby('title')['likes'].max().sort_values(ascending=False).head(1)
# Out:
# title
# BTS () 'Dynamite' Official MV    31837675
# Name: likes, dtype: int64

# %% [markdown]
# Inference: The title of the video which has the maximum number of likes is BTS () 'Dynamite' Official MV video with 3,18,37,675 likes.

# %%
# Using groupby function for title & likes columns, to find minimum videos of likes use .min() function.
# sort them using sort_values() give ascending = false, we get the video that has minimum likes using.tail(1)

df_copy.groupby('title')['likes'].min().sort_values(ascending=False).tail(1)
# Out:
# title
# Leading the Charge | Circle K    22
# Name: likes, dtype: int64

# %% [markdown]
# Inference: The title of the video which has the minimum number of likes is Leading the Charge | Circle K video with 22 likes.

# %% [markdown]
# Q12. Find the title of the video which has the maximum number of dislikes and the title of the video having
# minimum dislikes and write your inferences.

# %%
## Using groupby function for title & dislikes coulmns, to find maximum videos of dislikes use .max() function.
# sort them using sort_values() give ascending = false, we get the video that has maximum dislikes using.head(1)

df_copy.groupby('title')['dislikes'].max().sort_values(ascending=False).head(1)
# Out:
# title
# Cuties | Official Trailer | Netflix    2397733
# Name: dislikes, dtype: int64

# %% [markdown]
# Inference: The title of the video which has the maximum number of dislikes is Cuties | Official Trailer | Netflix with 23,97,733
# dislikes.

# %%
# Using groupby function for title & dislikes coulmns, to find minimum videos of likes use .min() function.
# sort them using sort_values() give ascending = false, we get the video that has minimum dislikes using.tail(1)

df_copy.groupby('title')['dislikes'].min().sort_values(ascending=False).tail(1)
# Out:
# title
# Tims For Good: A Taste Of The Familiar    3
# Name: dislikes, dtype: int64

# %% [markdown]
# Inference: The title of the video which has the minimum number of dislikes is Tims For Good: A Taste Of The Familiar with only 3 dislikes.

# %% [markdown]
# Q13. Does the number of views have any effect on how many people disliked the video? Support your
# answer with a metric and a plot.

# %%
# Use .corr() function to find the correlation between the coulmns and put a graph using scatter plot
df_copy.corr(numeric_only=True)
# Out:
#                view_count     likes  dislikes  comment_count
# view_count       1.000000  0.784199  0.684576       0.464442
# likes            0.784199  1.000000  0.679668       0.581117
# dislikes         0.684576  0.679668  1.000000       0.391999
# comment_count    0.464442  0.581117  0.391999       1.000000

# %%
# To get the comparision of relationship between 2 numerical values of (view_count & dislikes) we use scatter plot. 
sns.scatterplot(data=df_copy,x='view_count',y='dislikes')
plt.show()

# %% [markdown]
# By observing the plot we can stat that when the view_count of the video increases the rate of dislike is randomized which we can say for a lesser view_count the dislike count is high for few videos and for a higher view_count the dislike is approximately to its viewers rate of the viewers count

# %%
# by using seaborns and heatmap() function we can create it with the numerical columns
sns.heatmap(df_copy.corr(numeric_only=True),annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# Q14. Display all the information about the videos that were published in January, and mention the count of
# videos that were published in January.

# %%
# by taking published_month as jan we can find the information about the videos that were published in january.
df_copy[df_copy['published_month']=='Jan'].head()
# Out:
#         video_id                                              title  \
# 27   -2Gwm7QfBnE                                    Q&A With Naisha
# 48   -4sfXSHSxzA           SURPRISING BRENT WITH HIS TIKTOK CRUSH!!
# 95   -AJD1Fc5rpQ  WE ARE HAVING A BABY! | finding out i'm pregna...
# 103  -AuJiwjsmWk              Do Ugly Foods Taste Worse? Taste Test
# 182  -JhqO2KWr5U                                   Schlatt gets fit
#
#                    channel_id       channel_title        published_at  \
# 27   UCYwNMbogQFzMccPSuy-pPWg           MianTwins 2021-01-21 00:05:47
# 48   UCPpATKqmMV-CNRNWYaDUwiA        Alexa Rivera 2021-01-16 21:40:04
# 95   UCVsTboAhpnuL6j-tDePvNwQ      Tess Christine 2021-01-03 21:53:48
# 103  UCzpCc5n9hqiVC7HhPwcIKEg  Good Mythical MORE 2021-01-19 11:00:01
# 182  UCWZp4y1jqBuvLtiyxSs_ZBw             Big guy 2021-01-24 22:50:57
#
#      view_count   likes  dislikes  comment_count  \
# 27       872372   38626       239            621
# ...

# %%
# by calling the published_month with count() function again with video_id column, we can find the total count of videos published in january.

count_of_jan = df_copy['video_id'][df_copy['published_month'] == 'Jan'].count()
print("count of videos that were published in January:",count_of_jan)
# Out:
# count of videos that were published in January: 2099
