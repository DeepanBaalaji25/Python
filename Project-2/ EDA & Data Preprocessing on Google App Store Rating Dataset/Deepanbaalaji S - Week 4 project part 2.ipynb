# %% [markdown]
# ### Q1. Import required libraries and read the dataset.

# %%
# import all the necessary libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#to read the dataset we use .read_csv() function in pandas library.
df = pd.read_csv('C:/Users/deepa/Downloads/honeyproduction.csv')

# %%
# To display the dataframe we use df
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# ### Q2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
# .sample() function is used to see the df random datas
df.sample(10)
# Out:
#     state    numcol  yieldpercol   totalprod     stocks  priceperlb  \
# 372    OR   46000.0           48   2208000.0   729000.0        1.05
# 485    MO   11000.0           47    517000.0    57000.0        1.99
# 315    KY    5000.0           50    250000.0    40000.0        2.08
# 420    VA    6000.0           46    276000.0    63000.0        2.43
# 607    NE   43000.0           65   2795000.0  1146000.0        1.93
# 115    OH   18000.0           65   1170000.0   585000.0        0.79
# 365    NV    9000.0           37    333000.0    50000.0        3.62
# 138    IL    6000.0           76    456000.0   251000.0        1.58
# 378    VT    6000.0           56    336000.0   144000.0        1.20
# 104    MN  150000.0           90  13500000.0  3105000.0        0.57
#
#      prodvalue  year
# 372  2318000.0  2006
# 485  1029000.0  2009
# 315   520000.0  2005
# 420   671000.0  2007
# 607  5394000.0  2012
# 115   924000.0  2000
# 365  1205000.0  2006
# 138   720000.0  2001
# ...

# %%
# to find the shape(rows,columns) of the df we use .shape function is used.
df.shape
# Out:
# (626, 8)

# %%
# .info() function is used to find the information of the dataframe like datatypes, non-null values and rows,columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
df.nunique()
# Out:
# state           44
# numcol         148
# yieldpercol     95
# totalprod      517
# stocks         500
# priceperlb     210
# prodvalue      589
# year            15
# dtype: int64

# %% [markdown]
# ### Q3. Display the percentage distribution of the data in each year using the pie chart.

# %%
# values_counts() function is used to find the total values in each year
df['year'].value_counts()
# Out:
# year
# 2001    44
# 2002    44
# 2003    44
# 1998    43
# 1999    43
# 2000    43
# 2004    41
# 2005    41
# 2006    41
# 2007    41
# 2008    41
# 2009    40
# 2010    40
# 2011    40
# 2012    40
# Name: count, dtype: int64

# %%
# assigning x as variable and implying value_counts() of year into it.
x = df['year'].value_counts()

# assigning y as variable and adding years into it.
y = ['2001','2002','2003','1998','1999','2000','2004','2005','2006','2007','2008','2009','2010','2011','2012']

# using .pie() to create a peiplot to visually represent the data of year clearly, for a better view with percentage.
plt.pie(x, labels = y , autopct = '%.1f%%',pctdistance = 0.75,shadow = True,radius = 1.5)
plt.show()

# %% [markdown]
# ### Q4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
# creating a distribution plot using .displot() with priceperlb 
sns.displot(df['priceperlb'],kde=True)
plt.show()

# %% [markdown]
# Inference:
# 1. skewness :Positively skewed, were the trailing off to the right side of the plot.
# 2. kurtosis : Positive kurtosis, represents sharp peakness is around 1.25 - 1.5.
#  the count of the priceperlb peaks near 1.25 - 1.5 that part is considered as 'leptokurtic'.

# %% [markdown]
# ### Q5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
# .scatterplot() is used to understand the relationship between the 'numcol' and 'prodval'.
sns.scatterplot(data=df,x='numcol',y='prodvalue')
plt.show()

# %% [markdown]
# Observation:
# The Value of production (prodvalue) were maximum between the range of 0 - 1 is upto 0-150000 as Number of honey producing colonies(numcol) range.

# %% [markdown]
# ### Q6. Plot and understand the relationship between categorical variable 'year' and a numerical variable  'prodvalue' through boxplot, and write your findings.

# %%
# .boxplot() is used to find the outliers of each and every year.
sns.boxplot(data = df, x='year', y = 'prodvalue')
plt.show()

# %% [markdown]
# Observation:
# 1. We found out that every year has outliers and we can handle those outliers using log_transformation.
# 2. The median value for the year is around 0.01 - 0.20, they can be handled after using iqr method for q1, q2, q3 and min, median, max for year column with respect to production value.

# %% [markdown]
# ### Q7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
# .pairplot() used to find multiple realtionship between various coulmns frm the data
sns.pairplot(df, vars = ['numcol','yieldpercol','totalprod', 'prodvalue','year'])
plt.show()

# %% [markdown]
# Inference: By infering pairplot.
#
# 1. We can stat that the relationship between numcol and (prodvalue,totalprod) where numcol increases both prodvalue & totalprod increases.
# 2. Outliers are observed in the scatterplot year and numcol,yieldpercol,totalprod, indicating potential data points that may require further investigation.

# %% [markdown]
# ### Q8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
sns.heatmap(df[['numcol','yieldpercol','totalprod','stocks','priceperlb','prodvalue']].corr(),annot=True,fmt='.2f')
plt.show()

# %% [markdown]
# Inference:
# 1. There is a strong correlation pair between totalprod & numcol with 0.95.
# 2. The yieldpercol and priceperlb show a weak relation with -0.36.
